# %% [markdown]
# ![juliaLGLOgH%20%282%29.gif](attachment:juliaLGLOgH%20%282%29.gif)

# %%
using Pkg
Pkg.add("Plots")
using Plots

function parabol_hiperbol!(x::Int64, y::Int64)
    x^2 - y^2
end

function parabol_elip!(x::Int64, y::Int64)
    x^2 + y^2
end

function plot_elip()
    pe = plot3d(1, xlim=(-50,50), ylim=(-50,500), zlim=(-2500,2500),
                    title = "Paraboloide Elíptico", marker = 1)
    @gif for x = -50:50, y = -50:50
        z = parabol_elip!(x,y)
        push!(pe, float(x), float(y), float(z))
    end every 100
end

function plot_hiper()
    # initialize a 3D plot with 1 empty series
    ph = plot3d(1, xlim=(-50,50), ylim=(-50,500), zlim=(-2500,2500),
                    title = "Paraboloide Hiperbólico", marker = 1)
    @gif for x = -50:50, y = -50:50
        z = parabol_hiperbol!(x,y)
        push!(ph, float(x), float(y), float(z))
    end every 100
end

function plot_all()
    plot_elip()
    plot_hiper()
end

plot_all()
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]
# IOError: could not spawn `ffmpeg -v 0 -i /tmp/tmpleafe2/%06d.png -vf palettegen=stats_mode=diff -y /tmp/tmpleafe2/palette.bmp`: no such file or directory (ENOENT)
#
# Stacktrace:
#  [1] _jl_spawn(::String, ::Array{String,1}, ::Cmd, ::Tuple{RawFD,RawFD,RawFD}) at ./process.jl:367
#  [2] (::getfield(Base, Symbol("##494#495")){Cmd})(::Tuple{RawFD,RawFD,RawFD}) at ./process.jl:509
#  [3] setup_stdio(::getfield(Base, Symbol("##494#495")){Cmd}, ::Tuple{RawFD,RawFD,RawFD}) at ./process.jl:490
#  [4] #_spawn#493(::Nothing, ::Function, ::Cmd, ::Tuple{RawFD,RawFD,RawFD}) at ./process.jl:508
#  [5] _spawn at ./process.jl:504 [inlined]
#  [6] #run#504(::Bool, ::Function, ::Cmd) at ./process.jl:662
#  [7] run at ./process.jl:661 [inlined]
#  [8] #buildanimation#228(::Int64, ::Int64, ::Bool, ::Bool, ::Function, ::String, ::String, ::Bool) at /home/lu/.julia/packages/Plots/rmogG/src/animation.jl:82
#  [9] buildanimation at /home/lu/.julia/packages/Plots/rmogG/src/animation.jl:73 [inlined] (repeats 2 times)
#  [10] #gif#225 at /home/lu/.julia/packages/Plots/rmogG/src/animation.jl:63 [inlined]
#  [11] gif at /home/lu/.julia/packages/Plots/rmogG/src/animation.jl:63 [inlined] (repeats 2 times)
#  [12] macro expansion at ./In[3]:17 [inlined]
#  [13] macro expansion at /home/lu/.julia/packages/Plots/rmogG/src/animation.jl:155 [inlined]
#  [14] plot_elip() at ./In[3]:16
#  [15] plot_all() at ./In[3]:33
#  [16] top-level scope at In[3]:36
