# %%
using Pkg
Pkg.add("Plots")
using Plots
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
x = -3:0.1:3
f(x) = x^2

y = f.(x)
# Out:
# 61-element Array{Float64,1}:
#  9.0
#  8.41
#  7.839999999999999
#  7.290000000000001
#  6.760000000000001
#  6.25
#  5.76
#  5.289999999999999
#  4.840000000000001
#  4.41
#  4.0
#  3.61
#  3.24
#  ⋮
#  3.61
#  4.0
#  4.41
#  4.840000000000001
#  5.289999999999999
#  5.76
#  6.25
#  6.760000000000001
#  7.290000000000001
#  7.839999999999999
#  8.41
#  9.0

# %%
gr()
plot(x, y, label="linea")  
scatter!(x, y, label="puntos")

# %%
parabol_hiperbol!(x,y) = x^2 - y^2

parabol_elip!(x,y) = x^2 + y^2
# Out:
# parabol_elip! (generic function with 1 method)

# %%
# initialize a 3D plot with 1 empty series
ph = plot3d(1, xlim=(-50,50), ylim=(-50,500), zlim=(-2500,2500),
                title = "Paraboloide Hiperbólico", marker = 1)
@gif for x = -50:50, y = -50:50
    z = parabol_hiperbol!(x,y)
    push!(ph, float(x), float(y), float(z))
end every 100
# Out:
# ┌ Info: Saved animation to
# │   fn = /Users/taccini/Desktop/FIUBA/TDL/julia/examples/tmp.gif
# └ @ Plots /Users/taccini/.julia/packages/Plots/Ufx0i/src/animation.jl:90
# Plots.AnimatedGif("/Users/taccini/Desktop/FIUBA/TDL/julia/examples/tmp.gif")

# %%
pe = plot3d(1, xlim=(-50,50), ylim=(-50,500), zlim=(-2500,2500),
                title = "Paraboloide Elíptico", marker = 1)
@gif for x = -50:50, y = -50:50
    z = parabol_elip!(x,y)
    push!(pe, float(x), float(y), float(z))
end every 100
# Out:
# ┌ Info: Saved animation to
# │   fn = /Users/taccini/Desktop/FIUBA/TDL/julia/examples/tmp.gif
# └ @ Plots /Users/taccini/.julia/packages/Plots/Ufx0i/src/animation.jl:90
# Plots.AnimatedGif("/Users/taccini/Desktop/FIUBA/TDL/julia/examples/tmp.gif")
